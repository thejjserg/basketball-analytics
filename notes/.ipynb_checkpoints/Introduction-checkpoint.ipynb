# %% [markdown]
# # 🏀 Basketball Analytics Bootcamp — Week 0
#
# ## 📅 Date:
# 2025-10-10
#
# ## 🎯 Learning Objectives
# - Objective 1
# - Objective 2
# - Objective 3
#
# ---
#
# ## 📝 Key Topics Covered
# 1. Topic 1
# 2. Topic 2
# 3. Topic 3
#
# ---
#
# ## 📓 Detailed Notes
# ### Concept 1
# Explanation, formulas, or methodology.
#
# ### Concept 2
# Key points, diagrams, or step-by-step breakdowns.
#
# ---
#
# ## 💻 Code Examples
# ```python
# # Example: Import packages
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Example: Load basketball dataset
# df = pd.read_csv("data/sample_dataset.csv")
# df.head()
# ```
#
# ## 📊 Visualizations
# ```python
# # Example visualization
# sns.histplot(df['Points'], bins=20)
# plt.title("Points Distribution")
# plt.show()
# ```
#
# ## 📈 Insights & Takeaways
#
# - Insight 1
# - Insight 2
# - Insight 3
#
# ## 📚 References
#
# - Basketball Reference
# - NBA Stats API
# - Any readings, research papers, or class materials

# %% [markdown]
# # Introduction Meeting
# AJ Meyer
#
# Paulina is the program manager. Elyvtr representation.
#
# Zoom
# Onboarding Email - Course Program and Calendar
# Google Classroom
# Discord
# Q&A
#
# Chat is for Paulina
# Q&A is for AJ
#
# Meyer - May-her
#
# Camera is Optional but Encouraged
#
# We track attendance. Make sure your name is correct on Zoom.
#
# 2 Hours before we begin. Email with a link to the class. Link will be different each class.
#
# Onboarding email was sent out
#
# Be prepared to share why you took this class.
#
#
# Zoom Office Hours are the same Zoom link as the class that day
#
# Contact: Phone Number we were reached
# Google Calendar Bug?
#
# 646-762-0868

# %% [markdown]
# # Class 1
#
# ## Quiz
# 1. You can find the Zoom link in Classroom tab and **Stream** tab.
# 2. How can I check all the assignments sent by the instructor along with the grades I received for each assignment?
# - You can view all assignments the instructor has sent as well as the grades for each assignment in the Classwork tab by selecting the “View you work” button.
# 3. I can make edits to the assignment file once I turn it in *
# - If you need to make changes, you’ll need to UNSUBMIT the assignment first.
# 4. When and where can I find the link to the class recording?
#   - The link to the class recording will wait for you in the Classwork tab the day after the class.
# 5. Where can I find the password to the class recording? *
# - You can find the password to the class recording in Classwork and Stream tabs, displayed directly above the video thumbnail.
# 6. Can I download class recordings? *
# - You CAN’T download class recordings, but you can add them to your offline playlist with the Vimeo app and watch them wherever and whenever.
# - Please read the instructions [here](https://help.vimeo.com/hc/en-us/articles/12426003769361-iOS-app-viewer-features#h_01FRK92A4NYC4Z3MGT957HJJRE) to learn how you can do that.
# 7.
#
#
#
# ## Lecture
# - First time teaching the class
# - Using Analytics in the modern game
# - How can we best apply the data to win basketball games and make players better?
# - At the end of the day, it's just basektball from a data lense
#
# - Robbie Hunter, associate instructor
#
# ### Course Notes
# - You can use other player data for assignments. Let AJ know
# - This is going to have a focus of non-technical expertise. However, there are opportunities to be more technical
# - Class Project will be decided as we work throughout the course
# - Day-to-Day vs Long-Term, assignments will vary between these two ideas along with the courses
# - How are points determined? Criteria will be clear when assignments are assigned. There isn't a direct syllabus on the assignements except for the final
# - AJ was an assistant high school coach, went to Notre Dame as a Video Coordinator. Statistics and Economics major in university
# - Come to office hours, talk about the course, about basketball, engage with each other, debate with one another, and just get involved
# - Start with the box score, then expand to deeper levels
# -

# %% [markdown]
# # Class 1 - Introduction to Basketball Analytics
#
# ## Key Applications
# - Game Strategy
# 1. Pre-Game: Understanding opponent strtegnths, weaknesses, and tendencies. Not a substitute for film though
# 2. In-Game: Influencing strategy changes with data
# 3. Post Game: Analyzing strategy and execution after the game
#
# - Team Evaluation
# 1. Individual roles: How do we optimize the players we have?
# 2. Lineups: What combinations of players do we want to play? Which do we want to avoid?
# 3. Post-Game: Why did we win or lose the game? Did we execute our gameplan?
#
# - Scouting
# 1. Talent & Skill: How good is a player? What are their strengths and weaknesses?
# 2. Player Value: How much is a player worth? How do they fit within our salary cap/budget?
# 3. Fit: How does a player fit on court with our roster?
#
# - Player Development
# 1. Skill Identifiaction: In what areas does this player need to improve?
# 2. Prioritization: What should a player be working on?
# 3. Measuring Progress: How can we best measure a player's improvement over team?
#
# Notes:
# - Importance is determined by where the team is and where we are in the calendar.
# - Measuring Players for players that don't get a lot of time. If it's important, then how do you measure it?
#
#
# ## Tools and Software
#
# - Publicly Available Data
#   1. NBA.COM STATS
#   2. Basketball Refernce
#   3. Cleaning the Glass
#   4. PBPStats
# NBA.com has an API, it is free
# - Cleaning the Glass
#   1. Advanced Team & Player Stats
#   2. Removes "Garbage Time" (Minutes in the game that doesn't affect the game outcome)
#   3. Added Context Around Numbers
# - Basketball Reference
# 1.
#
# - pbpstats.com
# 1. Stats derived from play by play data
# 2. lineup context around metrics
# 3. aggregate stats across seasons
#
# **NCAA**
# 1. KENPOM
# 2. Sports Reference
# 3. CBB Analytics
# 4. Bart Torvik
#
# **Other Sources**
# 1. Synergy - Video Platform, highlight reels, lowlight reels
# 2. Second Spectrum - packages data from tracking cameras in arenas
# 3. NOAH - player development, shot tracking system, focused on ideal made shot
# 4. Shot Tracker - Chip in a basketball
# 5. Manual Tracking
# 6. Sports Radar - out of scope of the class
# 7. R and Python is primarily used as programming language, SQL is for databases
# 8. NBA.COM, PBP, basketball reference are free
#
#
# ## Evolution & Decision-Making
# 1. Size of Staffs,
# 2008, 5 total in NBA
# 2025, 5 per team, NBAStuffer.com
#
# ## Counting vs Estimated Stats
# Counting, simple stats
# Technical ability for more complex metrics (PBP Data available)
#
# Estimated, speed, larger datasets without technical resources, best option available (no PBP data)
#
#
# ## Tracking Data
# 1. Started with 6 cameras in every arena, up to 14 now
# 2. Tracks xyz of all 10 players and ball
# 3. 60 fps for precise locations
#
# ## Use Cases
# 1. More detail of already captured data
# 2. Algorithms to classify actions
# 3. Further detail about player and team tendencies
#
# We can compare more easily with PBP data and tracking.
# Manual tracking is still being used.
# How can you still a way to make the data that isn't expensive? A lot of times, there aren't data on college or high school players.
#
# ## What areas of basketball has analytics altered style of play?
#
#
#
# ## Moreyball
# - 2007 - Daryl Morey hired
# - Goal: Optimize roster construction and style of play through data
# - Find undervalued players that impact winning
# - Optimize strategies to win marginal points
#
#
# # Lab
# 1. Question 1 nbastats.com
# P.J. Tucker, 50%, but only 3 games
# KAT 42%, 72 games
# Landry Shamet, 39.7%, 50 games
# Brunson, 38.3%, 65 games
# OG Anunoby, 37.2% 74 games
#
# 2. nbastats.com
#
# Miles mCbride - 4 games, 22.9 minutes
# Jordan clarkson - 4 games, 17.1 minutes
#
#
#
# 4. Question 3 - BASKETBALL Reference
# Led team of assists, Brunson, 7.3 assists per game
# He had a streak of 8 games with 7+ assists
#
# 11/13/2024 vs chicago
# all the way to
# 11/27/2024 vs dallas
# High was 17 assists at Denver
#
#
#
# 4. NBASTATS.com
# Jalen Brunson - 26PPG,
# KAT - 24.4 PPG,
# OG Anunoby - 18 ppg
#
# KAT - 1759 TP
# Brunson - 1690 TP
# Bridges - 1444 TP
#
#
# 5. question 5, nbastats.com
#
# K. Towns - O. Anunoby - J. Hart - M. Bridges - J. Brunson
# 48 games
# 31 wins
# 17 losses
# 19.6 minutes together
# 47.6 ppg
#
# K. Towns - J. Hart - M. Bridges - J. Brunson - M. McBride
# 29 games
# 19 wins
# 10 losses
# 2.2 minutes together
# 6.3 ppg
#
# K. Towns - O. Anunoby - M. Bridges - J. Brunson - M. McBride
# 29 games
# 19 wins
# 10 losses
# 1.4 minutes together
# 3.7 ppg
#
#
# 6.
