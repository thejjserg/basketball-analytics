# %% [markdown]
# # Final Project: Analytics-Driven Coaching or Front Office Strategy
#
# **Description**: Choose your lane: lead like a coach or build like a GM. You’ll apply everything you’ve learned to create a full-fledged basketball strategy, backed by data and ready for real-world implementation.
#
# ### **Analytics-Driven Coaching**:
# Develop a data-driven strategy for how to best utilize an NBA roster for the following season.
#
# **GOAL**: Figure out what to prioritize and where to prioritize strategic initiatives for an NBA team's roster to provide to a Head Coach. Focus on factors like *optimizing shot selection*, *shooting efficiency*, *ball control*, *rebounding*, and *free throw performance* to maximize wins to fit a current NBA team.
#
# Make sure to include the following:
# 1. **Data Collection** from either or both [NBA Stats]() or [Basketball Reference]()
# 2. **Player Performance**: Evaluate individual player metrics to identify individual tendencies in the context of the team. Focus on creating reports on the top 8 players you would recommend playing in this team's rotation.
# 3. **Team General Strategy**: Note tactical and strategic adjustments based on optimizing your roster, whether those are consistent game-to-game or dynamic
# 4. **Lineup Analysis**: Assess combinations of players that have played together previously, as well as those that have not based on their demonstrated skills and metrics. Provide recommendations of 5-man lineups that would project to perform well as well as other combinations of players that you would recommend should or should not share the court.
# 5. **Game Specific Adjustments**: Where will your team struggle? How will you have to adjust to certain styles or opponent rosters?
# 6. **Visualizations**: Summarize important areas of data for this team in the form of static or dynamic visualizations.
#
#
# ### **Front Office Strategy**:
# Develop a data-driven roster strategy, incorporating evaluating player performance, draft prospects, free agents, and optimizing salary cap management for short- and / or long-term success.
#
# **GOAL**: Design a comprehensive roster plan that balances current performance, potential development, and salary cap efficiency to provide to a GM. Focus on factors like *maximizing player value relative to the market*, *prospect scouting*, *roster construction*, and *strategic planning*.
#
# Make sure to include the following:
# 1. **Data Collection** from either or both [NBA Stats]() or [Basketball Reference]()
# 2. **Player Valuation**: Assess the current roster utilizing basic and advanced metrics and provide recommendations for 3 Free Agents the team should look to sign
# 3. **Prospect Scouting**: Based on this team's positioning in the draft, analyze a draft prospect's fit with the team's needs and potential impact
# 4. **Roster Construction**: Evaluate two realistic trade opportunities and the projected impact on team performance and salary cap implications. Include reasoning of why this would benefit the trade partner to help both teams accomplish their goals
# 5. **Strategic Planning**: Illustrate a 3-Year Roadmap based on the status of the roster after following your recommendations
# 6. **Visualizations**: Present key insights in dashboards, charts, and graphs to simplify data
#
# -----------

# %% [markdown]
# ## 2024-2025 Season Recap
#
# The 2024–25 NBA season represented a major step forward for the Detroit Pistons. After finishing 14–68 (15th in the Eastern Conference) in 2023–24, the team improved to 44–38 (6th in the East) and successfully achieved its primary objective: returning to the Eastern Conference Playoffs.
#
# This leap was driven by the continued emergence of Cade Cunningham as a franchise cornerstone. Cunningham was voted in by Eastern Conference coaches as an All-Star Reserve, earned All-NBA Third Team honors, finished 3rd in the Most Improved Player voting, and placed 7th in MVP voting. His growth was solidified as the team’s offensive engine and late-game decision-maker.
#
# The supporting cast also made meaningful contributions. Malik Beasley finished 2nd for Sixth Man of the Year by providing floor spacing and a scoring punch off-the-bench, while J.B. Bickerstaff was recognized as the Coach of the Year runner-up, reflecting the team’s cultural and structural progress.
#
# From a team identity standpoint, the Pistons established themselves as a physical, defense-first group, finishing with a 113.1 Defensive Rating (11th league-wide). Offensively, the team was closer to league average (115.0 Offensive Rating, 16th), while playing at an above-average tempo (99.8 Pace, 9th). Overall, the Pistons posted a +1.9 Net Rating (13th) — a clear indicator of a competitive playoff-caliber team, but with room to grow.
#
# Detroit finished 4th in the Central Division, behind several strong playoff teams. With significant injuries and player movement affecting division rivals, this upcoming season presents a clear opportunity to capitalize on a favorable competitive window.
#
# The postseason ultimately exposed the team’s relative inexperience. The Pistons were unable to close out the New York Knicks at home, ending our playoff run earlier than we had hoped. While injuries played a role, the series highlighted areas where execution, lineup optimization, and late-game adjustments must improve.
#
# Looking ahead, the roster has undergone meaningful change. The team will move forward without key contributors: Malik Beasley, Tim Hardaway Jr., and Dennis Schröder, but gains stability with the return of Jaden Ivey and Isaiah Stewart from injury. Additionally, the acquisitions of Duncan Robinson and Caris LeVert add shooting versatility and secondary playmaking. Internally, the organization is optimistic about continued development from Jalen Duren, Ausar Thompson, and Ron Holland, each of whom will play a key role in shaping the next phase of the team’s identity.

# %% [markdown]
# ## Player Profiles
#
# ### Cade Cunningham
# **Traditional Box Score**
# Cade Cunningham finished the 2024–25 season averaging 26.1 PTS, 6.1 TRB, and 9.1 AST per game, while shooting 46.9% from-the-field and 35.6% from three. He functioned as the Pistons’ primary offensive engine and led the team in both scoring and playmaking responsibilities.
#
# **Per 100 Possessions**
# Per 100 possessions, Cunningham averaged 35.9 PTS, 8.3 TRB, and 12.5 AST, reinforcing his role as a high-usage initiator rather than a volume scorer operating in isolation. His Offensive Rating (112) and Defensive Rating (113) suggest neutral net impact at the possession level, consistent with a lead guard carrying a heavy offensive burden.
#
# **Advanced Statistics**
# Cunningham was the Pistons’ primary shot creator, posting a 33.2% Usage Rate while attempting 23.1 shots per game. His playmaking responsibilities also expanded significantly, as his Assist Percentage jumped to 43%, a career high and a 5.5% increase from the previous season.
#
# As expected for a high-usage guard, Cunningham’s turnover volume was elevated. He averaged 4.4 TOV per game, resulting in a 16% Turnover Rate, the second-highest among NBA players last season. While some of this is an inherent tradeoff of offensive responsibility, reducing live-ball turnovers through improved decision speed and reads against pressure represents a clear area for efficiency gains.
#
# **Adjusted Shooting**
# Cunningham produced solid scoring efficiency given his usage, posting a 52.2% eFG% and 56.4% TS%. He was particularly effective at the free-throw line, converting 84.6% of his attempts, and generated consistent pressure on the rim with a 25.4% Free Throw Rate. This combination indicates a scorer who can sustain efficiency even without elite shooting splits, largely due to foul drawing and shot diversity.
#
# **Shooting**
# Cunningham’s shot diet (FGA) leaned heavily toward intermediate areas of the floor:
# - 16.7% at-the-rim (60.5% FG%)
# - 36.2% paint-shots, 3–10 feet (49.7% FG%)
# - 12.9% from short, mid-range (10 feet to 16 feet) (47.9% FG%)
# - 5.6% from long, mid-range (16 feet to the three-point line) (44.4% FG%)
# - 28.7% from three (35.6% 3P%)
#
# **Play-by-Play**
# Cunningham played 84% of his minutes at point guard, clearly functioning as the team’s primary initiator. His On-Court +/- per 100 possessions (+3.4) and On-Off differential (+3.7) indicate that the team performed meaningfully better with him on the floor, reinforcing his value beyond raw box score production.
#
# 62.2% of Cunningham’s TOV came from bad passes, highlighting that many mistakes occurred during playmaking rather than ball-handling or scoring attempts. This further supports the idea that streamlining reads and reducing high-risk passes could materially improve offensive efficiency without sacrificing usage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def plot_shooting_profile_from_excel(
    excel_path: str,
    player_name: str,
    season: str = "2024-25",
    sheet_name: str = "Shooting"
):
    df = pd.read_excel(excel_path, sheet_name=sheet_name)

    required_cols = [
        "Season",
        "%FGA-by-Distance_0-3",
        "%FGA-by-Distance_3-10",
        "%FGA-by-Distance_10-16",
        "%FGA-by-Distance_16-3P",
        "%FGA-by-Distance_3P",
        "FG%-by-Distance_0-3",
        "FG%-by-Distance_3-10",
        "FG%-by-Distance_10-16",
        "FG%-by-Distance_16-3P",
        "FG%-by-Distance_3P",
    ]
    missing = [c for c in required_cols if c not in df.columns]
    if missing:
        raise ValueError(f"Missing expected columns in '{sheet_name}': {missing}")

    df = df.dropna(subset=["Season"]).copy()
    match = df[df["Season"].astype(str) == str(season)]
    if match.empty:
        raise ValueError(
            f"Season '{season}' not found. Seasons available: {sorted(df['Season'].astype(str).unique())}"
        )
    row = match.iloc[0]

    dist_labels = ["0-3", "3-10", "10-16", "16-3P", "3P"]

    # Shot distribution (should sum to ~1.0 already)
    dist_shares = np.array([
        row["%FGA-by-Distance_0-3"],
        row["%FGA-by-Distance_3-10"],
        row["%FGA-by-Distance_10-16"],
        row["%FGA-by-Distance_16-3P"],
        row["%FGA-by-Distance_3P"],
    ], dtype=float)

    # Normalize in case rounding makes sum != 1
    s = np.nansum(dist_shares)
    if s > 0:
        dist_shares = dist_shares / s

    # FG% by distance (decimal form)
    dist_fg = np.array([
        row["FG%-by-Distance_0-3"],
        row["FG%-by-Distance_3-10"],
        row["FG%-by-Distance_10-16"],
        row["FG%-by-Distance_16-3P"],
        row["FG%-by-Distance_3P"],
    ], dtype=float)

    # ----------------------------
    # Chart 1: PIE (FGA split)
    # ----------------------------
    plt.figure(figsize=(8, 6))
    plt.pie(
        dist_shares,
        labels=dist_labels,
        autopct=lambda p: f"{p:.1f}%"
    )
    plt.title(f"{player_name} FGA")
    plt.show()

    # ----------------------------
    # Chart 2: BAR (FG% by distance)
    # ----------------------------
    plt.figure(figsize=(8, 5))
    x = np.arange(len(dist_labels))
    plt.bar(x, dist_fg)
    plt.xticks(x, dist_labels)
    plt.ylim(0, 1)
    plt.ylabel("FG% (decimal)")
    plt.title(f"{player_name} FG%")
    plt.show()

    # Optional: quick printed summary row for debugging/QA
    summary = pd.DataFrame({
        "Distance": dist_labels,
        "%FGA": dist_shares,
        "FG%": dist_fg
    })
    print(f"Summary used for charts ({player_name}, {season}):")
    print(summary.to_string(index=False))

# %% [markdown]
# if __name__ == "__main__":
#     plot_shooting_profile_from_excel(
#         excel_path="Cade Cunningham.xlsx",
#         player_name="Cade Cunningham"
#         # season defaults to "2024-25"
#     )

# %%
def plot_player_trend(
    excel_file,
    sheetname,
    stat_column,
    y_label,
    title,
    x_column = "Season",
    first_season=None,
    last_season=None,
    y_min=0,
    y_max=None,
    filename=None
):
    import os
    import pandas as pd
    import matplotlib.pyplot as plt

    # Read data
    df = pd.read_excel(excel_file, sheet_name=sheetname)

    # Create numeric season key
    df["Season_Start"] = df["Season"].str[:4].astype(int)

    # Apply season filters
    if first_season is not None:
        df = df[df["Season_Start"] >= first_season]

    if last_season is not None:
        df = df[df["Season_Start"] <= last_season]

    # Sort correctly
    df = df.sort_values("Season_Start")

    # Handle percentages
    y_values = df[stat_column]
    if y_values.max() <= 1:
        y_values = y_values * 100

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(df[x_column], y_values, marker="o", linewidth=2)

    plt.xlabel(x_column)
    plt.ylabel(y_label)
    plt.title(title)
    plt.ylim(bottom=y_min)

    if y_max is not None:
        plt.ylim(top=y_max)

    plt.grid(True, alpha=0.3)

    # Save
    if filename:
        os.makedirs("Charts", exist_ok=True)
        plt.savefig(f"Charts/{filename}", dpi=300, bbox_inches="tight")

    plt.show()

# %% [markdown]
# players = ["Cade Cunningham", "Duncan Robinson", "Ausar Thompson", "Tobias Harris", "Jalen Duren", "Isaiah Stewart", "Jaden Ivey", "Ron Holland"]
# for player in players:
#     plot_player_trend(
#     excel_file=(player + ".xlsx"),
#     stat_column="FG%-by-Distance_3P",
#     y_label="3P%",
#     title= player + " – 3PT Shooting Trend",
#     first_season=2020,
#     last_season=2024,
#     y_min=0,
#     y_max=45,
#     filename=player + "_3P_Trend_2021_2024.png"
# )

# %% [markdown]
# plot_player_trend(
#     excel_file="Cade Cunningham.xlsx",
#     stat_column="FG%",
#     y_label="FG%",
#     title="Cade Cunningham – Field Goal Percentage Over Time",
#     first_season = None,
#     last_season = None,
#     y_min = 20,
#     y_max = 50,
#     filename="Cade_FG_Percentage_All_Seasons.png"
# )

# %%
plot_player_trend(
    excel_file="Cade Cunningham.xlsx",
    sheetname = "Play-by-Play",
    stat_column="BadPass_PCT",
    y_label="Bad Pass TOV%",
    title="Cade Cunningham – Bad Pass TOV%",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = 100,
    filename="Cade_Bad_Pass_TOV%.png"
)

plot_player_trend(
    excel_file="Cade Cunningham.xlsx",
    sheetname = "Play-by-Play",
    stat_column="BadPass_Turnovers",
    y_label="Number of Bad Pass TOV",
    title="Cade Cunningham – Number of Bad Pass TOVs",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = None,
    filename="Cade_Num_Bad_Pass_TOV.png"
)

plot_player_trend(
    excel_file="Cade Cunningham.xlsx",
    sheetname = "Play-by-Play",
    stat_column="LostBall_PCT",
    y_label="Lost Ball TOV%",
    title="Cade Cunningham – Lost Ball TOV%",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = 100,
    filename="Cade_Lost_Ball_TOV%.png"
)

plot_player_trend(
    excel_file="Cade Cunningham.xlsx",
    sheetname = "Play-by-Play",
    stat_column="LostBall_Turnovers",
    y_label="Number of Lost Ball TOV",
    title="Cade Cunningham – Number of Lost Ball TOVs",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = None,
    filename="Cade_Num_Lost_Ball_TOV.png"
)

# %%
def shot_attempts(fga, fta):
    shot_attempts = fga + 0.44*fta
    return shot_attempts

# %%
# Duncan Robinson Shot Attempts
duncan_robinson = pd.read_excel("Duncan Robinson.xlsx", sheet_name = "Per Game")
duncan_robinson["Shot Attempts"] = duncan_robinson.apply(
    lambda row: shot_attempts(
        fga = row["FGA"],
        fta = row["FTA"]
    ),
    axis = 1
)
duncan_robinson.head()
# Out:
#     Season  Age Team   Lg Pos   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0  2018-19   24  MIA  NBA  SF  15   1  10.7  1.2   3.1  ...  1.1  1.3  0.3
# 1  2019-20   25  MIA  NBA  SG  73  68  29.7  4.4   9.4  ...  3.0  3.2  1.4
# 2  2020-21   26  MIA  NBA  SF  72  72  31.4  4.4  10.0  ...  3.4  3.5  1.8
# 3  2021-22   27  MIA  NBA  SG  79  68  25.9  3.7   9.2  ...  2.3  2.6  1.6
# 4  2022-23   28  MIA  NBA  SF  42   1  16.5  2.1   5.6  ...  1.5  1.6  1.1
#
#    STL  BLK  TOV   PF   PTS  Awards  Shot Attempts
# 0  0.3  0.0  0.3  0.7   3.3     NaN          3.276
# 1  0.5  0.3  1.0  2.6  13.5     NaN          9.840
# 2  0.6  0.3  1.1  2.5  13.1     NaN         10.440
# 3  0.5  0.2  0.8  2.5  10.9     NaN          9.552
# 4  0.3  0.0  0.7  1.8   6.4     NaN          5.952
#
# [5 rows x 32 columns]

# %%
plot_player_trend(
    excel_file="Duncan Robinson.xlsx",
    sheetname = "Shooting",
    stat_column="%-of-FG-Ast'd_2P",
    y_label="2P FG Assisted On %",
    title="Duncan Robinson – 2P FG Assisted On",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = 100,
    filename="Robinson_2P_Assisted%.png"
)

plot_player_trend(
    excel_file="Duncan Robinson.xlsx",
    sheetname = "Shooting",
    stat_column="%-of-FG-Ast'd_3P",
    y_label="3P FG Assisted On %",
    title="Duncan Robinson – 3P FG Assisted On",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = 100,
    filename="Robinson_3P_Assisted%.png"
)

# %%
# Ausar Thompson Shot Attempts
ausar_thompson = pd.read_excel("Ausar Thompson.xlsx", sheet_name = "Per Game")
ausar_thompson["Shot Attempts"] = ausar_thompson.apply(
    lambda row: shot_attempts(
        fga = row["FGA"],
        fta = row["FTA"]
    ),
    axis = 1
)
ausar_thompson.head()
# Out:
#     Season  Age Team   Lg Pos   G  GS    MP   FG  FGA  ...  DRB  TRB  AST  \
# 0  2023-24   21  DET  NBA  SF  63  38  25.1  3.7  7.6  ...  4.3  6.4  1.9
# 1  2024-25   22  DET  NBA  SF  59  48  22.5  4.2  7.8  ...  3.3  5.1  2.3
# 2  2025-26   23  DET  NBA  SF  36  35  25.9  4.4  8.8  ...  3.8  5.8  2.6
#
#    STL  BLK  TOV   PF   PTS  Awards  Shot Attempts
# 0  1.1  0.9  1.3  2.8   8.8     NaN          8.436
# 1  1.7  0.7  1.4  2.8  10.1     NaN          8.856
# 2  1.6  0.8  1.6  2.9  10.9     NaN         10.296
#
# [3 rows x 32 columns]

# %%
plot_player_trend(
    excel_file="Ausar Thompson.xlsx",
    sheetname = "Adjusted Shooting",
    stat_column="Shooting%_3P%",
    y_label="3P%",
    title="Ausar Thompson - 3P%",
    first_season = None,
    last_season = 2024,
    y_min = 0,
    y_max = 100,
    filename="Ausar_3P%.png"
)

# %%
# Tobias Harris Shot Attempts
tobias_harris = pd.read_excel("Tobias Harris.xlsx", sheet_name = "Per Game")
tobias_harris["Shot Attempts"] = tobias_harris.apply(
    lambda row: shot_attempts(
        fga = row["FGA"],
        fta = row["FTA"]
    ),
    axis = 1
)
tobias_harris
# Out:
#      Season  Age Team   Lg Pos   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0   2011-12   19  MIL  NBA  SF  42   9  11.4  1.9   4.0  ...  1.7  2.4  0.5
# 1   2012-13   20  2TM  NBA  SF  55  34  23.6  4.2   9.3  ...  3.9  5.2  1.3
# 2   2012-13   20  MIL  NBA  SF  28  14  11.6  1.9   4.1  ...  1.4  2.0  0.5
# 3   2012-13   20  ORL  NBA  PF  27  20  36.1  6.7  14.7  ...  6.4  8.5  2.1
# 4   2013-14   21  ORL  NBA  PF  61  36  30.3  5.4  11.7  ...  5.5  7.0  1.3
# 5   2014-15   22  ORL  NBA  SF  68  63  34.8  6.5  14.0  ...  5.3  6.3  1.8
# 6   2015-16   23  2TM  NBA  PF  76  74  33.1  5.5  11.7  ...  5.4  6.7  2.2
# 7   2015-16   23  ORL  NBA  PF  49  49  32.9  5.1  11.0  ...  5.5  7.0  2.0
# 8   2015-16   23  DET  NBA  PF  27  25  33.4  6.1  12.9  ...  5.3  6.2  2.6
# 9   2016-17   24  DET  NBA  PF  82  48  31.3  6.2  13.0  ...  4.3  5.1  1.7
# 10  2017-18   25  2TM  NBA  PF  80  80  33.4  7.0  15.3  ...  4.7  5.5  2.4
# 11  2017-18   25  DET  NBA  PF  48  48  32.6  6.7  14.8  ...  4.3  5.1  2.0
# 12  2017-18   25  LAC  NBA  PF  32  32  34.5  7.6  16.0  ...  5.3  6.0  3.1
# 13  2018-19   26  2TM  NBA  PF  82  82  34.7  7.5  15.3  ...  7.0  7.9  2.8
# 14  2018-19   26  LAC  NBA  PF  55  55  34.6  7.7  15.5  ...  7.2  7.9  2.7
# 15  2018-19   26  PHI  NBA  PF  27  27  35.0  6.9  14.8  ...  6.7  7.9  2.9
# 16  2019-20   27  PHI  NBA  PF  72  72  34.3  7.7  16.3  ...  5.9  6.9  3.2
# 17  2020-21   28  PHI  NBA  PF  62  62  32.5  7.6  14.9  ...  5.8  6.8  3.5
# 18  2021-22   29  PHI  NBA  PF  73  73  34.8  6.8  14.0  ...  5.7  6.8  3.5
# 19  2022-23   30  PHI  NBA  SF  74  74  32.9  5.7  11.4  ...  4.8  5.7  2.5
# 20  2023-24   31  PHI  NBA  PF  70  70  33.8  6.6  13.6  ...  5.3  6.5  3.1
# 21  2024-25   32  DET  NBA  PF  73  73  31.6  5.3  11.0  ...  5.0  5.9  2.2
# 22  2025-26   33  DET  NBA  PF  25  25  27.1  4.8  10.4  ...  3.6  4.7  2.5
#
#     STL  BLK  TOV   PF   PTS  Awards  Shot Attempts
# 0   0.3  0.2  0.7  1.1   5.0     NaN          4.572
# 1   0.6  0.8  1.2  2.2  11.0     NaN         10.400
# 2   0.3  0.3  0.6  1.1   4.9     NaN          4.496
# 3   0.9  1.4  1.8  3.3  17.3     NaN         16.504
# 4   0.7  0.4  1.3  2.3  14.6     NaN         13.460
# 5   1.0  0.5  1.7  2.0  17.1     NaN         15.584
# 6   0.9  0.5  1.4  2.0  14.7     NaN         13.108
# 7   1.0  0.6  1.6  1.9  13.7     NaN         12.364
# 8   0.7  0.4  1.1  2.3  16.6     NaN         14.352
# 9   0.7  0.5  1.2  1.6  16.1     NaN         14.232
# 10  0.9  0.4  1.3  2.1  18.6     NaN         16.488
# 11  0.7  0.3  1.1  1.9  18.1     NaN         16.032
# 12  1.2  0.6  1.7  2.3  19.3     NaN         17.100
# 13  0.6  0.5  1.8  2.2  20.0     NaN         16.928
# 14  0.7  0.4  2.0  2.2  20.9     NaN         17.260
# 15  0.4  0.5  1.6  2.3  18.2     NaN         16.252
# 16  0.7  0.6  1.4  2.3  19.6     NaN         17.620
# 17  0.9  0.8  1.7  1.9  19.5     NaN         16.352
# 18  0.6  0.6  1.6  2.2  17.2     NaN         15.232
# 19  0.9  0.5  1.2  2.0  14.7     NaN         12.148
# 20  1.0  0.7  1.3  1.6  17.2     NaN         14.920
# 21  1.0  0.8  1.2  1.9  13.7     NaN         12.012
# 22  0.8  0.2  1.0  2.0  13.3     NaN         11.632
#
# [23 rows x 32 columns]

# %%
plot_player_trend(
    excel_file="Tobias Harris.xlsx",
    sheetname = "Advanced",
    stat_column="TRB%",
    y_label="TRB%",
    title="Tobias Harris - TRB%",
    first_season = 2019,
    last_season = 2024,
    y_min = 0,
    y_max = 20,
    filename="Tobias_TRB%.png"
)

plot_player_trend(
    excel_file="Tobias Harris.xlsx",
    sheetname = "Advanced",
    stat_column="USG%",
    y_label="USG%",
    title="Tobias Harris - USG%",
    first_season = 2019,
    last_season = 2024,
    y_min = 0,
    y_max = 30,
    filename="Tobias_USG%.png"
)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("NBA-2024-25-Rookies.xlsx")
df = df[df["G"] >= 50]

plt.figure(figsize=(10, 6))

plt.scatter(
    df["STL_Total"].astype(float),
    df["BLK_Total"].astype(float)
)

x_offset = 0.05   # move right
y_offset = 0.25   # move up

# Label each point with player name
for _, row in df.iterrows():
    plt.text(
        row["STL_Total"] + x_offset,
        row["BLK_Total"] + y_offset,
        row["Player"],
        fontsize=8,
        alpha=0.7
    )

plt.xlabel("Total Steals")
plt.ylabel("Total Blocks")
plt.title("Total Stocks for 2024-25 NBA Rookies")
plt.grid(True)

plt.xlim(0, 125)   # Typical USG% range
plt.ylim(0, 125)   # Typical TS% range


plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Read Rookie Data
df = pd.read_excel("NBA-2024-25-Rookies.xlsx")

def rookie_holland_scatter(
    rookies: pd.DataFrame,
    player_name: str = "Ron Holland",
    min_mp: int = 200,                 # filter out tiny samples
    filename: str | None = None,       # e.g., "rookie_holland_scatter.png"
    charts_folder: str = "Charts"
):
    data = rookies.copy()

    # --- Ensure numeric types ---
    numeric_cols = [
        "MP_Total", "FGA_Total", "3PA_Total", "STL_Total", "BLK_Total",
        "FTA_Total", "PTS_Total", "AST_Total", "TOV_Total"
    ]
    for col in numeric_cols:
        if col in data.columns:
            data[col] = pd.to_numeric(data[col], errors="coerce")

    # --- Filter for meaningful sample ---
    if "MP_Total" not in data.columns:
        raise ValueError("Missing required column: 'MP_Total'")
    data = data[data["MP_Total"] >= min_mp].dropna(subset=["MP_Total", "FGA_Total"])

    # --- Derived metrics from totals ---
    data["3PAr"] = np.where(data["FGA_Total"] > 0, data["3PA_Total"] / data["FGA_Total"], np.nan)
    data["Stocks_per_36"] = np.where(
        data["MP_Total"] > 0,
        (data["STL_Total"] + data["BLK_Total"]) / data["MP_Total"] * 36,
        np.nan
    )

    # Optional extras (kept here for later use)
    data["TS%"] = np.where(
        (data["FGA_Total"] + 0.44 * data["FTA_Total"]) > 0,
        data["PTS_Total"] / (2 * (data["FGA_Total"] + 0.44 * data["FTA_Total"])),
        np.nan
    )
    data["AST_TOV"] = np.where(data["TOV_Total"] > 0, data["AST_Total"] / data["TOV_Total"], np.nan)

    # --- Identify target player ---
    if "Player" not in data.columns:
        raise ValueError("Missing required column: 'Player'")

    is_target = data["Player"].astype(str).str.strip().eq(player_name)

    # --- Plot ---
    plt.figure(figsize=(10, 6))

    # Everyone else
    plt.scatter(
        data.loc[~is_target, "3PAr"],
        data.loc[~is_target, "Stocks_per_36"],
        s=np.clip(data.loc[~is_target, "MP_Total"] / 3, 20, 500),
        alpha=0.35
    )

    # Target player highlight
    if is_target.any():
        plt.scatter(
            data.loc[is_target, "3PAr"],
            data.loc[is_target, "Stocks_per_36"],
            s=np.clip(data.loc[is_target, "MP_Total"] / 3, 120, 900),
            alpha=0.95
        )
        x = data.loc[is_target, "3PAr"].iloc[0]
        y = data.loc[is_target, "Stocks_per_36"].iloc[0]
        plt.text(x, y, f"  {player_name}", va="center", fontsize=11)

    plt.title(f"Rookie Class: Defensive Activity vs 3PT Role (min {min_mp} MP)")
    plt.xlabel("3PA Rate")
    plt.ylabel("Stocks per 36")
    plt.grid(True, alpha=0.2)

    # --- Save to Charts folder if filename provided ---
    if filename:
        os.makedirs(charts_folder, exist_ok=True)
        out_path = os.path.join(charts_folder, filename)
        plt.savefig(out_path, dpi=200, bbox_inches="tight")
        print(f"Saved chart to: {out_path}")

    plt.show()

# Test run
rookie_holland_scatter(
    df,
    player_name="Ron Holland",
    min_mp=300,
    filename="rookie_holland_scatter.png"
)
# Out:
# Saved chart to: Charts/rookie_holland_scatter.png

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Read Team Game Log Data
team = pd.read_excel("Pistons_Team_Data.xlsx", sheet_name = "Pistons Game Log - 2024-25")
opp = pd.read_excel("Pistons_Team_Data.xlsx", sheet_name = "Opponent Game Log - 2024-25")

# Join team and opponent game logs
games = team.merge(
    opp,
    on="Rk",
    how="inner",
    suffixes=("_TEAM", "_OPP")
)

# Check Join
print(games.shape)      # Should be (82, 59 columns)
games.head()
# Out:
# (82, 59)
#    Rk  Gtm_TEAM  Date_TEAM Location_TEAM Opp_TEAM Rslt_TEAM  Tm_TEAM  \
# 0   1         1 2024-10-23           NaN      IND         L      109
# 1   2         2 2024-10-25             @      CLE         L      101
# 2   3         3 2024-10-26           NaN      BOS         L      118
# 3   4         4 2024-10-28             @      MIA         L       98
# 4   5         5 2024-10-30             @      PHI         W      105
#
#    Opp.1_TEAM OT_TEAM  FG_TEAM  ...  FTA_OPP  FT%_OPP  ORB_OPP  DRB_OPP  \
# 0         115     NaN       38  ...       25    0.880        7       32
# 1         113     NaN       38  ...       23    0.696        5       34
# 2         124     NaN       43  ...       30    0.867       13       24
# 3         106     NaN       35  ...       20    0.750       10       34
# 4          95     NaN       36  ...       28    0.750        8       29
#
#    TRB_OPP  AST_OPP  STL_OPP  BLK_OPP  TOV_OPP  PF_OPP
# 0       39       32       10        8       15      23
# 1       39       28       13        4       13      15
# 2       37       19       10        6       10      16
# 3       44       24       14        3       12      14
# 4       37       17        7        4        9      21
#
# [5 rows x 59 columns]

# %%
games.columns
# Out:
# Index(['Rk', 'Gtm_TEAM', 'Date_TEAM', 'Location_TEAM', 'Opp_TEAM', 'Rslt_TEAM',
#        'Tm_TEAM', 'Opp.1_TEAM', 'OT_TEAM', 'FG_TEAM', 'FGA_TEAM', 'FG%_TEAM',
#        '3P_TEAM', '3PA_TEAM', '3P%_TEAM', '2P_TEAM', '2PA_TEAM', '2P%_TEAM',
#        'eFG%_TEAM', 'FT_TEAM', 'FTA_TEAM', 'FT%_TEAM', 'ORB_TEAM', 'DRB_TEAM',
#        'TRB_TEAM', 'AST_TEAM', 'STL_TEAM', 'BLK_TEAM', 'TOV_TEAM', 'PF_TEAM',
#        'Gtm_OPP', 'Date_OPP', 'Location_OPP', 'Opp_OPP', 'Rslt_OPP', 'Tm_OPP',
#        'Opp.1_OPP', 'OT_OPP', 'FG_OPP', 'FGA_OPP', 'FG%_OPP', '3P_OPP',
#        '3PA_OPP', '3P%_OPP', '2P_OPP', '2PA_OPP', '2P%_OPP', 'eFG%_OPP',
#        'FT_OPP', 'FTA_OPP', 'FT%_OPP', 'ORB_OPP', 'DRB_OPP', 'TRB_OPP',
#        'AST_OPP', 'STL_OPP', 'BLK_OPP', 'TOV_OPP', 'PF_OPP'],
#       dtype='object')

# %%
games["Poss_TEAM"] = games["FGA_TEAM"] + 0.44 * games["FTA_TEAM"] + games["TOV_TEAM"] - games["ORB_TEAM"]
games["Poss_OPP"] = games["FGA_OPP"] + 0.44 * games["FTA_OPP"] + games["TOV_OPP"] - games["ORB_OPP"]

# Scoring & Shooting
games["FG%_Diff"]  = games["FG%_TEAM"]  - games["FG%_OPP"]
games["3P%_Diff"]  = games["3P%_TEAM"]  - games["3P%_OPP"]
games["eFG%_Diff"] = games["eFG%_TEAM"] - games["eFG%_OPP"]

# Possessions & Control
games["TOV%_TEAM"] = games["TOV_TEAM"] / games["Poss_TEAM"]
games["TOV%_OPP"] = games["TOV_OPP"] / games["Poss_OPP"]
games["TOV_Diff"] = games["TOV%_TEAM"] - games["TOV%_OPP"]

# ORB 
games["ORB_Diff"] = games["ORB_TEAM"] / (games["ORB_TEAM"] + games["DRB_OPP"]) - games["ORB_OPP"] / (games["ORB_OPP"] + games["DRB_TEAM"])
#games["ORB%_Team"] = games["ORB_TEAM"] / games["ORB_OPP"]
games["TRB_Diff"] = games["TRB_TEAM"] - games["TRB_OPP"]

# Ball Movement & Disruption
games["AST_Diff"] = games["AST_TEAM"] - games["AST_OPP"]
games["STL_Diff"] = games["STL_TEAM"] - games["STL_OPP"]
games["BLK_Diff"] = games["BLK_TEAM"] - games["BLK_OPP"]

# Physicality and Fouling
games["PF_Diff"] = games["PF_TEAM"] - games["PF_OPP"]

# Point Margin (positive = Pistons win, negative = Pistons loss)
games["Point_Margin"] = games["Tm_TEAM"] - games["Opp.1_TEAM"]


# Free Throws
games["FTR_TEAM"] = games["FTA_TEAM"] / games["FGA_TEAM"]
games["FTR_OPP"] = games["FTA_OPP"] / games["FGA_OPP"]

games["FTR_Diff"] = games["FTR_TEAM"] - games["FTR_OPP"]

# %%
games.columns
# Out:
# Index(['Rk', 'Gtm_TEAM', 'Date_TEAM', 'Location_TEAM', 'Opp_TEAM', 'Rslt_TEAM',
#        'Tm_TEAM', 'Opp.1_TEAM', 'OT_TEAM', 'FG_TEAM', 'FGA_TEAM', 'FG%_TEAM',
#        '3P_TEAM', '3PA_TEAM', '3P%_TEAM', '2P_TEAM', '2PA_TEAM', '2P%_TEAM',
#        'eFG%_TEAM', 'FT_TEAM', 'FTA_TEAM', 'FT%_TEAM', 'ORB_TEAM', 'DRB_TEAM',
#        'TRB_TEAM', 'AST_TEAM', 'STL_TEAM', 'BLK_TEAM', 'TOV_TEAM', 'PF_TEAM',
#        'Gtm_OPP', 'Date_OPP', 'Location_OPP', 'Opp_OPP', 'Rslt_OPP', 'Tm_OPP',
#        'Opp.1_OPP', 'OT_OPP', 'FG_OPP', 'FGA_OPP', 'FG%_OPP', '3P_OPP',
#        '3PA_OPP', '3P%_OPP', '2P_OPP', '2PA_OPP', '2P%_OPP', 'eFG%_OPP',
#        'FT_OPP', 'FTA_OPP', 'FT%_OPP', 'ORB_OPP', 'DRB_OPP', 'TRB_OPP',
#        'AST_OPP', 'STL_OPP', 'BLK_OPP', 'TOV_OPP', 'PF_OPP', 'Poss_TEAM',
#        'Poss_OPP', 'FG%_Diff', '3P%_Diff', 'eFG%_Diff', 'TOV%_TEAM',
#        'TOV%_OPP', 'TOV_Diff', 'ORB_Diff', 'TRB_Diff', 'AST_Diff', 'STL_Diff',
#        'BLK_Diff', 'PF_Diff', 'Point_Margin', 'FTR_TEAM', 'FTR_OPP',
#        'FTR_Diff'],
#       dtype='object')

# %%
# Filter for Losses
losses = games[games["Rslt_TEAM"] == "L"]

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    games["eFG%_Diff"],
    games["Point_Margin"],
    alpha=0.75
)

plt.axvline(0, linestyle="--")
plt.axhline(0, linestyle="--")

plt.title("eFG% Differential vs Point Margin")
plt.xlabel("eFG% Differential (Pistons - Opponent)")
plt.ylabel("Point Margin (Pistons)")

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    games["TOV_Diff"],
    games["Point_Margin"]
)

plt.axhline(0)
plt.axvline(0)

plt.xlabel("TOV% Differential (Pistons - Opponent)")
plt.ylabel("Point Margin (Pistons)")
plt.title("TOV% Differential vs Point Margin")

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    games["ORB_Diff"],
    games["Point_Margin"]
)

plt.axhline(0)
plt.axvline(0)

plt.xlabel("ORB% (Pistons - Opponent)")
plt.ylabel("Point Margin (Pistons)")
plt.title("ORB% vs Point Margin")

plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    games["FTR_Diff"],
    games["Point_Margin"],
    alpha=0.7
)

# Reference lines
plt.axhline(0)
plt.axvline(0)

plt.title("FTR Differential vs Point Margin")
plt.xlabel("FTR Differential (Pistons - Opponent)")
plt.ylabel("Point Margin (Pistons)")

plt.show()
